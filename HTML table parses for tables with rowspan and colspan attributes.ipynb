# %% [markdown]
# ## Robust HTML table parser code for tables with rowspan and/or colspans
# In scouring the web, it was to the embarrasment of humanity that I could not find a parser that could accurately parse the tables found on Wikipedia such as [Wisconsin_political_power](https://en.wikipedia.org/wiki/Political_party_strength_in_Wisconsin); I thus wrote my own.

# %%
##Libraries used are:
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# ### Parser functions

# %%
def pre_process_table(table):
    """
    INPUT:
        1. table - a bs4 element that contains the desired table: ie <table> ... </table>
    OUTPUT:
        a tuple of: 
            1. rows - a list of table rows ie: list of <tr>...</tr> elements
            2. num_rows - number of rows in the table
            3. num_cols - number of columns in the table
    """
    rows = [x for x in table.find_all('tr')]

    num_rows = len(rows)
    num_cols = max([len(x.find_all('th')) for x in rows])
    
    return (rows, num_rows, num_cols)


def get_spans(cell):
        """
        INPUT:
            1. cell - a <td>...</td> or <th>...</th> element that contains a table cell entry
        OUTPUT:
            1. a tuple with the cell's row and col spans
        """
        if cell.has_attr('rowspan'):
            rep_row = int(cell.attrs['rowspan'])
        else: # ~cell.has_attr('rowspan'):
            rep_row = 1
        if cell.has_attr('colspan'):
            rep_col = int(cell.attrs['colspan'])
        else: # ~cell.has_attr('colspan'):
            rep_col = 1 
        
        return (rep_row, rep_col)
 
def process_rows(rows, num_rows, num_cols):
    """
    INPUT:
        1. rows - a list of table rows ie <tr>...</tr> elements
    OUTPUT:
        1. data - a Pandas dataframe with the html data in it
    """
    data = pd.DataFrame(np.ones((num_rows, num_cols))*np.nan)
    for i, row in enumerate(rows):
        col_stat = data.iloc[i,:][data.iloc[i,:].isnull()].index[0]

        for j, cell in enumerate(row.find_all(['td', 'th'])):
            rep_row, rep_col = get_spans(cell)

            #print("cols {0} to {1} with rep_col={2}".format(col_stat, col_stat+rep_col, rep_col))
            #print("\trows {0} to {1} with rep_row={2}".format(i, i+rep_row, rep_row))

            #find first non-na col and fill that one
            while any(data.iloc[i,col_stat:col_stat+rep_col].notnull()):
                col_stat+=1

            data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
            if col_stat<data.shape[1]-1:
                col_stat+=rep_col

    return data

# %% [markdown]
# ### Example:
# Here, I will parse the HTML table linked in the description.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests

def fetch_website(url):
    """
    To hide that the scraping is being done via Python, I change the user-agent to a Firefox
    browser so that the website believes it is a chrome browser accessing them. Hope it works.
    """
    user_agent={'User-agent':'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.18 Safari/537.36'}
    r=requests.get(url, headers=user_agent)
    try:
        #print("Accessed and downloaded URL data")
        return(r.content)
    except ConnectionError:
        print("Skipping this url")
        return(None)

# %%
## Go to the link and download the page's html code:
url = "https://en.wikipedia.org/wiki/Political_party_strength_in_Wisconsin"
site = fetch_website(url)
soup = bs(site, 'lxml')

# %%
## Find tables on the page and locate the desired one:
## Caveat: note that I explicitly search for a wikitable!  
tables = soup.findAll("table", class_='wikitable')

## I want table 3 or the one that contains years 2000-2018
table = tables[3]

# %%
## run the above functions to extract the data
rows, num_rows, num_cols = pre_process_table(table)
df = process_rows(rows, num_rows, num_cols)

## print the result
df
# Out:
#       0                   1                      2                     3   \
# 0   Year   Executive offices      Executive offices     Executive offices
# 19          Brad Schimel (R)     Matt Adamczyk (R)           19R, 14D
# 20          Brad Schimel (R)     Matt Adamczyk (R)           20R, 13D
# 21          Brad Schimel (R)     Matt Adamczyk (R)           20R, 13D
# 22          Attorney General             Treasurer       State Senate
# 23         Executive offices     Executive offices  State Legislature
#
#                    7                       8                         9   \
# 0   State Legislature  United States Congress    United States Congress
# 1      State Assembly  U.S. Senator (Class I)  U.S. Senator (Class III)
# 2            55R, 44D           Herb Kohl (D)         Russ Feingold (D)
# 3            56R, 43D           Herb Kohl (D)         Russ Feingold (D)
# 4            56R, 43D           Herb Kohl (D)         Russ Feingold (D)
# 5            58R, 41D           Herb Kohl (D)         Russ Feingold (D)
# 6            58R, 41D           Herb Kohl (D)         Russ Feingold (D)
# 7            60R, 39D           Herb Kohl (D)         Russ Feingold (D)
# 8            60R, 39D           Herb Kohl (D)         Russ Feingold (D)
# 9            52R, 47D           Herb Kohl (D)         Russ Feingold (D)
# 10           52R, 47D           Herb Kohl (D)         Russ Feingold (D)
# 11       52D, 46R, 1I           Herb Kohl (D)         Russ Feingold (D)
# 12       52D, 46R, 1I           Herb Kohl (D)         Russ Feingold (D)
# 13       59R, 39D, 1I           Herb Kohl (D)           Ron Johnson (R)
# 14       59R, 39D, 1I           Herb Kohl (D)           Ron Johnson (R)
# 15       59R, 39D, 1I           Herb Kohl (D)           Ron Johnson (R)
# 16           60R, 39D       Tammy Baldwin (D)           Ron Johnson (R)
# 17           60R, 39D       Tammy Baldwin (D)           Ron Johnson (R)
# 18           63R, 36D       Tammy Baldwin (D)           Ron Johnson (R)
# 19           63R, 36D       Tammy Baldwin (D)           Ron Johnson (R)
# 20           64R, 35D       Tammy Baldwin (D)           Ron Johnson (R)
# 21           64R, 35D       Tammy Baldwin (D)           Ron Johnson (R)
# 22     State Assembly  U.S. Senator (Class I)  U.S. Senator (Class III)
# 23  State Legislature  United States Congress    United States Congress
#
#                         10                       11
# 0   United States Congress  Electoral College votes
# 1               U.S. House  Electoral College votes
# 2                   5D, 4R     Gore/Lieberman (D) N
# 3                   5D, 4R     Gore/Lieberman (D) N
# 4                   5D, 4R     Gore/Lieberman (D) N
# 5                   4R, 4D     Gore/Lieberman (D) N
# 6                   4R, 4D      Kerry/Edwards (D) N
# 7                   4R, 4D      Kerry/Edwards (D) N
# 8                   4R, 4D      Kerry/Edwards (D) N
# 9                   5D, 3R      Kerry/Edwards (D) N
# 10                  5D, 3R        Obama/Biden (D) Y
# 11                  5D, 3R        Obama/Biden (D) Y
# 12                  5D, 3R        Obama/Biden (D) Y
# 13                  5R, 3D        Obama/Biden (D) Y
# 14                  5R, 3D        Obama/Biden (D) Y
# 15                  5R, 3D        Obama/Biden (D) Y
# 16                  5R, 3D        Obama/Biden (D) Y
# 17                  5R, 3D        Obama/Biden (D) Y
# 18                  5R, 3D        Obama/Biden (D) Y
# 19                  5R, 3D        Trump/Pence (R) Y
# 20                  5R, 3D        Trump/Pence (R) Y
# 21                  5R, 3D        Trump/Pence (R) Y
# 22              U.S. House  Electoral College votes
# 23  United States Congress  Electoral College votes
